# %%
from datetime import datetime
a = set()
b = set()
n = int(input("Enter the number of students: "))
for i in range(n):
    name = input("Enter the name of the student: ")
    clean_name = name.lower().replace(" ", "")
    current_time = datetime.now().strftime("%H:%M:%S")
    if clean_name in a:
        b.add(clean_name)
        print(f"[{current_time}] {clean_name} is FAKE (already exists)")
    else:
        a.add(clean_name)
        print(f"[{current_time}] {clean_name} is REAL (added successfully)")
print("\nReal students:", a)
print("Fake students:", b)
# Out:
# Enter the number of students: 3
# Enter the name of the student: Ankit
# [10:11:34] ankit is REAL (added successfully)
# Enter the name of the student: Amit
# [10:11:48] amit is REAL (added successfully)
# Enter the name of the student: Ankit
# [10:11:55] ankit is FAKE (already exists)
#
# Real students: {'amit', 'ankit'}
# Fake students: {'ankit'}
