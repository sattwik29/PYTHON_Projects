# %%
list = ["apple", 2.87, 34]
print(list)
for x in list:
  print(x)
  print(type(x))
# Out:
# ['apple', 2.87, 34]
# apple
# <class 'str'>
# 2.87
# <class 'float'>
# 34
# <class 'int'>

# %% [markdown]
# ### Simple `split()` Example

# %%
simple_text = "apple banana cherry"
split_words = simple_text.split()
print(f"Original: '{simple_text}'")
print(f"Split by space: {split_words}")
# Out:
# Original: 'apple banana cherry'
# Split by space: ['apple', 'banana', 'cherry']

# %% [markdown]
# ### Simple `partition()` Example

# %%
simple_phrase = "Python is fun"
part_before, separator, part_after = simple_phrase.partition(' is ')
print(f"Before separator: '{part_before}', Separator: '{separator}', After separator: '{part_after}'")
# Out:
# Original: 'Python is fun'
# Before separator: 'Python', Separator: ' is ', After separator: 'fun'

# %%
lst=[1,2,3,1]
if lst==lst[::-1]:
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# Not Palindrome

# %%
my_list = [1, 2, 3]
print(f"Original list: {my_list}")
my_list.append(4)
print(f"After append(4): {my_list}")
my_list.append([5, 6])
print(f"After append([5, 6]): {my_list}")
my_list_2 = [10, 20, 30]
print(f"\nOriginal list for extend: {my_list_2}")
my_list_2.extend([40, 50])
print(f"After extend([40, 50]): {my_list_2}")
my_list_2.extend("abc")
print(f"After extend(\"abc\"): {my_list_2}")
# Out:
# Original list: [1, 2, 3]
# After append(4): [1, 2, 3, 4]
# After append([5, 6]): [1, 2, 3, 4, [5, 6]]
#
# Original list for extend: [10, 20, 30]
# After extend([40, 50]): [10, 20, 30, 40, 50]
# After extend("abc"): [10, 20, 30, 40, 50, 'a', 'b', 'c']

# %%
account_balance = 1000  # Initial account balance

def deposit(amount):
    global account_balance
    if amount > 0:
        account_balance += amount
        print(f"Deposit successful. New balance: ${account_balance}")
    else:
        print("Deposit amount must be positive.")

def withdraw(amount):
    global account_balance
    if amount > 0:
        if account_balance >= amount:
            account_balance -= amount
            print(f"Withdrawal successful. New balance: ${account_balance}")
        else:
            print("Insufficient funds.")
    else:
        print("Withdrawal amount must be positive.")

def check_balance():
    print(f"Current account balance: ${account_balance}")


print("Welcome to the ATM!")

# Password section
correct_password = "1234" # You can change this password
max_attempts = 3
attempts = 0

while attempts < max_attempts:
    password = input("Enter your 4-digit PIN: ")
    if password == correct_password:
        print("PIN accepted. You can now access the ATM functions.")
        break
    else:
        attempts += 1
        print(f"Incorrect PIN. {max_attempts - attempts} attempts remaining.")
else:
    print("Too many incorrect attempts. Your card is blocked.")
    exit() # Exit the program if too many incorrect attempts

# ATM functionality
while True:
    print("\nSelect an option:")
    print("1. Check Balance")
    print("2. Deposit")
    print("3. Withdraw")
    print("4. Exit")

    choice = input("Enter your choice (1-4): ")

    if choice == '1':
        check_balance()
    elif choice == '2':
        try:
            amount = float(input("Enter amount to deposit: "))
            deposit(amount)
        except ValueError:
            print("Invalid amount. Please enter a number.")
    elif choice == '3':
        try:
            amount = float(input("Enter amount to withdraw: "))
            withdraw(amount)
        except ValueError:
            print("Invalid amount. Please enter a number.")
    elif choice == '4':
        print("Thank you for using the ATM. Goodbye!")
        break
    else:
        print("Invalid choice. Please enter a number between 1 and 4.")
# Out:
# Welcome to the ATM!
#
# Select an option:
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Deposit successful. New balance: $1286.0
#
# Select an option:
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Current account balance: $1286.0
#
# Select an option:
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Withdrawal successful. New balance: $1186.0
#
# Select an option:
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Deposit successful. New balance: $4840.0
#
# Select an option:
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit

# %%
balance=0
transaction=[]
while True:
  print("\n1.Deposit")
  print("2.Withdraw")
  print("3.Check Balance")
  print("4.Transaction history")
  print("5.Exit")

  choice=int(input("Enter your choice: "))

  if choice==1:
    amount=int(input("Enter amount to deposit: "))
    balance+=amount
    transaction.append("Deposited :"+ str(amount))
  elif choice==2:
    amount=int(input("Enter amount to withdraw: "))
    if amount<=balance:
      balance-=amount
      transaction.append("Withdrawl :"+ str(amount))
    else:
      print("Insufficient balance")
  elif choice==3:
    print(f"Current balance: {balance}")
  elif choice==4:
    print("Transaction history:")
    for t in transaction:
      print(t)
  else:
    print("Exit")
# Out:
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction history
# 5.Exit
# Enter your choice: 1
# Enter amount to deposit: 3000
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction history
# 5.Exit
# Enter your choice: 2
# Enter amount to withdraw: 297
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction history
# 5.Exit
# Enter your choice: 3
# Current balance: 2703
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Transaction history
# 5.Exit

# %%
balance = 0
transactions = []
correct_password = "1234"
attempts = 3

# Password verification
while attempts > 0:
    entered_password = input("Enter your password: ")

    if entered_password == correct_password:
        print("Login successful!")
        break
    else:
        attempts -= 1
        print(f"Wrong password! Attempts left: {attempts}")

# If all attempts are used
if attempts == 0:
    print("Too many wrong attempts. Access denied.")
else:
    # ATM Menu
    while True:
        print("\n1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Transaction History")
        print("5. Exit")

        choice = int(input("Enter your choice: "))

        if choice == 1:
            amount = int(input("Enter amount to deposit: "))
            if amount > 0:
                balance += amount
                transactions.append("Deposited: " + str(amount))
            else:
                print("Invalid amount")

        elif choice == 2:
            amount = int(input("Enter amount to withdraw: "))
            if amount <= balance and amount > 0:
                balance -= amount
                transactions.append("Withdrawal: " + str(amount))
            else:
                print("Insufficient balance or invalid amount")

        elif choice == 3:
            print(f"Current balance: {balance}")

        elif choice == 4:
            print("Transaction history:")
            if not transactions:
                print("No transactions yet")
            else:
                for t in transactions:
                    print(t)

        elif choice == 5:
            print("Thank you! Exiting...")
            break

        else:
            print("Invalid choice. Try again.")
# Out:
# Enter your password: 1
# Wrong password! Attempts left: 2
# Enter your password: 1234
# Login successful!
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 1
# Enter amount to deposit: 3000
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 2
# Enter amount to withdraw: 300
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# Enter your choice: 3
# Current balance: 2700
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Transaction History
# 5. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2700431653.py in <cell line: 0>()
#      27         print("5. Exit")
#      28
# ---> 29         choice = int(input("Enter your choice: "))
#      30
#      31         if choice == 1:
#
# ...

# %%
'''WRITE A PROGRAM TO MAKE A STRING INPUT FROM THE USER AND PRINT IT INVERSE .
WAP TO COUNT THE NUMBER OF UPPERCASE AND LOWERCASE CHARACTERS IN A STRING
WAP TO CHECK WHETHER A GIVEN STRING CONTAINS ONLY DIGITS
WAP TO REPLACE ALL SPACES IN A STRING WITH UNDERSCORE
WAP TO COUNT THE FREQUENCY OF EACH CHARACTER IN A STRING
WAP TO FIND THE FIRST AND LAST OCCURANCE OF A CHARACTER IN A STRING
WAP TO REMOVE ALL VOWELS FROM A GIVEN STRING
WAP TO CHECK WHETHER 2 STRINGS ARE ANAGRAMS OF EACH OTHER
WAP TO CAPITALIZED THE FIRST LETTER OF EACH WORD IN A STRING
WAP TO CHECK WHETHER A GIVEN STRING IS PALINDROME WITHOUT USING BUILT-IN REVERSE FUNCTION
''''

# %%
s = input("Enter a string: ")
rev = ""
for ch in s:
    rev = ch + rev
print("Reversed string:", rev)
# Out:
# Enter a string: mama
# Reversed string: amam

# %%
s = input("Enter a string: ")
upper = 0
lower = 0

for ch in s:
    if ch.isupper():
        upper += 1
    elif ch.islower():
        lower += 1

print("Uppercase:", upper)
print("Lowercase:", lower)
# Out:
# Enter a string: Ankit
# Uppercase: 1
# Lowercase: 4

# %%
s = input("Enter a string: ")

if s.isdigit():
    print("String contains only digits")
else:
    print("String does not contain only digits")
# Out:
# Enter a string: Ankit Sahu
# String does not contain only digits

# %%
s = input("Enter a string: ")
print(s.replace(" ", "_"))
# Out:
# Enter a string: Ankit Sahu
# Ankit_Sahu

# %%
s = input("Enter a string: ")

for ch in s:
    print(ch, ":", s.count(ch))
# Out:
# Enter a string: Hello PYTHON
# H : 2
# e : 1
# l : 2
# l : 2
# o : 1
#   : 1
# P : 1
# Y : 1
# T : 1
# H : 2
# O : 1
# N : 1

# %%
s = input("Enter a string: ")
ch = input("Enter character: ")

print("First occurrence:", s.find(ch))
print("Last occurrence:", s.rfind(ch))
# Out:
# Enter a string: How are u
# Enter character: e
# First occurrence: 6
# Last occurrence: 6

# %%
s = input("Enter a string: ")
result = ""

for ch in s:
    if ch.lower() not in "aeiou":
        result += ch

print("String without vowels:", result)
# Out:
# Enter a string: ankit
# String without vowels: nkt

# %%
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

if sorted(s1) == sorted(s2):
    print("Strings are anagrams")
else:
    print("Strings are not anagrams")
# Out:
# Enter first string: hello
# Enter second string: python
# Strings are not anagrams

# %%
s = input("Enter a string: ")
print(s.title())
# Out:
# Enter a string: ankit sahu
# Ankit Sahu

# %%
s = input("Enter a string: ")
flag = True

for i in range(len(s)//2):
    if s[i] != s[len(s)-1-i]:
        flag = False
        break

if flag:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a string: aman
# Not Palindrome

# %%
numbers_tuple = (10, 20, 30, 40)
numbers_list = list(numbers_tuple)
numbers_list.append(50)
numbers_tuple = tuple(numbers_list)
print(numbers_tuple)
# Out:
# (10, 20, 30, 40, 50)

# %%
s = input("Enter a string: ")
vowels = 0
consonants = 0

for char in s:
    if char.isalpha(): # Check if the character is an alphabet
        char_lower = char.lower()
        if char_lower in 'aeiou':
            vowels += 1
        else:
            consonants += 1

print("Number of vowels:", vowels)
print("Number of consonants:", consonants)
# Out:
# Enter a string: apple
# Number of vowels: 2
# Number of consonants: 3

# %%
a=set()#entered_student
b=set()#rejected_student
n=int(input("Enter the number of student:"))
for i in range(n):
  name=input("Enter the student name:")
  if name in a:
    print("Already exist.")
  else:
    a.add(name)
print("Entered students",a)
print("Rejected students",b)
# Out:
# Enter the number of student:2
# Enter the student name:ankit
# Enter the student name:Amit
# Entered students {'Amit', 'ankit'}
# Rejected students set()
